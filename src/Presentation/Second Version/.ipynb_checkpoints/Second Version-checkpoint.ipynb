# %%
from keras.layers import Conv2D, Conv2DTranspose, UpSampling2D
from keras.layers import Activation, Dense, Dropout, Flatten, InputLayer
from keras.layers.normalization import BatchNormalization
from keras.callbacks import TensorBoard
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf

import PIL
from PIL import Image
import shutil
# Out:
# Using TensorFlow backend.

# %%
# Get images
images = []
for filename in os.listdir('../images/Images_version_5/Train/'):
    img = Image.open('../images/Images_version_5/Train/'+filename)
    w, h = img.size
    if w != 256 or h != 256:
        print(filename)
    images.append(img_to_array(load_img('../images/Images_version_5/Train/'+filename)))   
print(len(images))

images = np.array(images, dtype=float)

# Set up train data
images_train = images

# 1.0/255 -> 24 bit RGB color, [0-255] for each color channel -> 16.7m combinations -> human can recognize 2-10m 
images_train = 1.0/255*images_train
# Out:
# 999

# %%
# build neuronal net - first create Sequential() model
model = Sequential()
#define an input layer (only once) - input data have shape of 256x256
# be aware that convolutional takes a 3D input so we need to shape to 256x256 and 1 for 1 color space
#model.add(InputLayer(input_shape=(256, 256, 1)))
# 1st filter, 2st kernel space (3,3) <-- size of filter
# activation relu
# padding - output from kernel will decrease - padding does that it will fill up to like 28x28
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(256, 256, 1)))
# strides -> nr or tuple - how much kernel should be moved (2 px)
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(2, (3, 3), activation='tanh', padding='same'))
model.add(UpSampling2D((2, 2)))
model.compile(optimizer='rmsprop', loss='mse' , metrics=["accuracy"])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 128)       147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 256)       1179904
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 128)       295040
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 128, 128, 32)      18464
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 2)       578
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 256, 256, 2)       0
# =================================================================
# Total params: 3,892,194
# Trainable params: 3,892,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

# Setup ImageDataGenerator
# How does it work?
#    1) accepting batch of images
#    2) apply random transformation to each image
#    3) replace original batch we newly transformed batch
#    4) train CNN on newly transformed batch

dataGenerator = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=20,
    shear_range=0.2,
    zoom_range=0.2
)

# define batch size
batch_size = 10

# define function to call ImagedataGenerator
def imageGenerator(batch_size):
    for batch in dataGenerator.flow(images_train, batch_size=batch_size):
        # be aware that we have rgb colored photos, to work better we 
        # call rgb2lab function which converts image to a lab image with a b color channel
        # # Lab color, L -> grayscale layer, a b -> color layers (green-red, blue-yellow)
        lab_of_batch = rgb2lab(batch)
        # extract b/w layer for Xbatch
        Xbatch = lab_of_batch[:,:,:,0] # [:,:,:,0] -> select grayscale layer
        # extract two color layer for Ybatch
        # ab spectrum [-128,128] .. divide by 128 to get [-1,1]
        Ybatch = lab_of_batch[:,:,:,1:]/128 # [:,:,:,1] -> select color layer
        # return generator object
        yield(Xbatch.reshape(Xbatch.shape+(1,)), Ybatch)

# Train
filepath = "model_1409.h5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# keras support 3 types of training
#   1.fit, 2. fit_generator, 3. train_on_batch

# to train on large models .fit would not be suitable because RAM overfilled

# .fit_generator - here data is no longer “static” — the data is constantly changing
# Each new batch of data is randomly adjusted according to the parameters supplied to ImageDataGenerator
# .fit_generator accepts the batch of data, performs backpropagation, and updates the weights in our model

# .train_on_batch -- fine-grained control over training your deep learning models - mostly not suitable

history = model.fit_generator(imageGenerator(batch_size), epochs=500, steps_per_epoch=10, verbose=1, callbacks=callbacks_list)
# Out:
# Epoch 1/500
# 10/10 [==============================] - 74s 7s/step - loss: 0.0116 - accuracy: 0.7374
# Epoch 2/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0117 - accuracy: 0.7156
# Epoch 3/500
# 10/10 [==============================] - 68s 7s/step - loss: 0.0114 - accuracy: 0.7113
# Epoch 4/500
# 10/10 [==============================] - 64s 6s/step - loss: 0.0108 - accuracy: 0.7273
# Epoch 5/500
# 10/10 [==============================] - 70s 7s/step - loss: 0.0098 - accuracy: 0.7458
# Epoch 6/500
# 10/10 [==============================] - 70s 7s/step - loss: 0.0104 - accuracy: 0.7217
# Epoch 7/500
# 10/10 [==============================] - 70s 7s/step - loss: 0.0103 - accuracy: 0.7108
# Epoch 8/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0112 - accuracy: 0.7212
# Epoch 9/500
# 10/10 [==============================] - 70s 7s/step - loss: 0.0111 - accuracy: 0.7062
# Epoch 10/500
# 10/10 [==============================] - 70s 7s/step - loss: 0.0105 - accuracy: 0.7558
# Epoch 11/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0093 - accuracy: 0.7033
# Epoch 12/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0121 - accuracy: 0.7898
# Epoch 13/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0108 - accuracy: 0.7101
# Epoch 14/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0111 - accuracy: 0.7444
# Epoch 15/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0115 - accuracy: 0.7589
# Epoch 16/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0103 - accuracy: 0.7262
# Epoch 17/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0101 - accuracy: 0.6999
# Epoch 18/500
# 10/10 [==============================] - 70s 7s/step - loss: 0.0120 - accuracy: 0.7286
# Epoch 19/500
# 10/10 [==============================] - 70s 7s/step - loss: 0.0099 - accuracy: 0.6729
# Epoch 20/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0095 - accuracy: 0.7243
# Epoch 21/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0097 - accuracy: 0.7241
# Epoch 22/500
# 10/10 [==============================] - 70s 7s/step - loss: 0.0115 - accuracy: 0.7461
# Epoch 23/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0113 - accuracy: 0.6858
# Epoch 24/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0112 - accuracy: 0.7350
# Epoch 25/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0112 - accuracy: 0.7129
# Epoch 26/500
# 10/10 [==============================] - 71s 7s/step - loss: 0.0121 - accuracy: 0.7517
# Epoch 27/500
# 10/10 [==============================] - 70s 7s/step - loss: 0.0108 - accuracy: 0.7356
# Epoch 28/500
# 10/10 [==============================] - 28s 3s/step - loss: 0.0099 - accuracy: 0.7099
# Epoch 29/500
# 10/10 [==============================] - 26s 3s/step - loss: 0.0111 - accuracy: 0.7452
# Epoch 30/500
# 10/10 [==============================] - 26s 3s/step - loss: 0.0122 - accuracy: 0.7556
# Epoch 31/500
# 10/10 [==============================] - 26s 3s/step - loss: 0.0122 - accuracy: 0.7174
# Epoch 32/500
# 10/10 [==============================] - 26s 3s/step - loss: 0.0118 - accuracy: 0.7362
# Epoch 33/500
# 10/10 [==============================] - 26s 3s/step - loss: 0.0100 - accuracy: 0.7257
# Epoch 34/500
# 10/10 [==============================] - 28s 3s/step - loss: 0.0093 - accuracy: 0.7080
# Epoch 35/500
# 10/10 [==============================] - 34s 3s/step - loss: 0.0110 - accuracy: 0.7247
# Epoch 36/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0090 - accuracy: 0.6856
# Epoch 37/500
# 10/10 [==============================] - 35s 3s/step - loss: 0.0094 - accuracy: 0.7292
# Epoch 38/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0111 - accuracy: 0.7459
# Epoch 39/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0102 - accuracy: 0.7443
# Epoch 40/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0104 - accuracy: 0.7341
# Epoch 41/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0107 - accuracy: 0.7035
# Epoch 42/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0101 - accuracy: 0.7298
# Epoch 43/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0131 - accuracy: 0.6463
# Epoch 44/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0108 - accuracy: 0.7567
# Epoch 45/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0117 - accuracy: 0.7518
# Epoch 46/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0103 - accuracy: 0.7311
# Epoch 47/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0099 - accuracy: 0.7406
# Epoch 48/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0096 - accuracy: 0.6946
# Epoch 49/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0113 - accuracy: 0.7269
# Epoch 50/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0122 - accuracy: 0.7230
# Epoch 51/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0093 - accuracy: 0.7322
# Epoch 52/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0114 - accuracy: 0.7112
# Epoch 53/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0144 - accuracy: 0.7500
# Epoch 54/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0097 - accuracy: 0.7208
# Epoch 55/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0094 - accuracy: 0.7420
# Epoch 56/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0093 - accuracy: 0.7383
# Epoch 57/500
# 10/10 [==============================] - 45s 4s/step - loss: 0.0110 - accuracy: 0.7120
# Epoch 58/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0096 - accuracy: 0.7434
# Epoch 59/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0120 - accuracy: 0.6818
# Epoch 60/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0117 - accuracy: 0.7391
# Epoch 61/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0099 - accuracy: 0.7374
# Epoch 62/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0098 - accuracy: 0.7394
# Epoch 63/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0155 - accuracy: 0.7407
# Epoch 64/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0109 - accuracy: 0.7287
# Epoch 65/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0109 - accuracy: 0.7050
# Epoch 66/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0108 - accuracy: 0.7287
# Epoch 67/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0094 - accuracy: 0.7236
# Epoch 68/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0105 - accuracy: 0.7124
# Epoch 69/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0101 - accuracy: 0.7538
# Epoch 70/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0098 - accuracy: 0.7362
# Epoch 71/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0112 - accuracy: 0.7449
# Epoch 72/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0119 - accuracy: 0.7534
# Epoch 73/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0105 - accuracy: 0.6775
# Epoch 74/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0144 - accuracy: 0.7489
# Epoch 75/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0106 - accuracy: 0.6797
# Epoch 76/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0108 - accuracy: 0.7536
# Epoch 77/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0102 - accuracy: 0.7508
# Epoch 78/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0106 - accuracy: 0.7714
# Epoch 79/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0118 - accuracy: 0.7600
# Epoch 80/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0127 - accuracy: 0.7324
# Epoch 81/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0116 - accuracy: 0.7525
# Epoch 82/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0092 - accuracy: 0.6943
# Epoch 83/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0109 - accuracy: 0.6659
# Epoch 84/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0098 - accuracy: 0.7153
# Epoch 85/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0106 - accuracy: 0.7091
# Epoch 86/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0101 - accuracy: 0.7295
# Epoch 87/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0115 - accuracy: 0.7203
# Epoch 88/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0161 - accuracy: 0.7419
# Epoch 89/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0107 - accuracy: 0.7072
# Epoch 90/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0107 - accuracy: 0.7261
# Epoch 91/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0099 - accuracy: 0.7102
# Epoch 92/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0119 - accuracy: 0.6986
# Epoch 93/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0111 - accuracy: 0.7624
# Epoch 94/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0110 - accuracy: 0.7374
# Epoch 95/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0125 - accuracy: 0.7454
# Epoch 96/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0113 - accuracy: 0.7463
# Epoch 97/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0138 - accuracy: 0.7083
# Epoch 98/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0104 - accuracy: 0.7259
# Epoch 99/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0117 - accuracy: 0.7431
# Epoch 100/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0109 - accuracy: 0.7222
# Epoch 101/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0098 - accuracy: 0.7222
# Epoch 102/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0114 - accuracy: 0.6750
# Epoch 103/500
# 10/10 [==============================] - 45s 4s/step - loss: 0.0109 - accuracy: 0.7242
# Epoch 104/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0099 - accuracy: 0.7616
# Epoch 105/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0109 - accuracy: 0.7397
# Epoch 106/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0141 - accuracy: 0.7328
# Epoch 107/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0115 - accuracy: 0.7244
# Epoch 108/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0112 - accuracy: 0.7256
# Epoch 109/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0100 - accuracy: 0.7357
# Epoch 110/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0111 - accuracy: 0.7237
# Epoch 111/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0116 - accuracy: 0.7059
# Epoch 112/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0107 - accuracy: 0.7160
# Epoch 113/500
# 10/10 [==============================] - 47s 5s/step - loss: 0.0123 - accuracy: 0.7550
# Epoch 114/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0111 - accuracy: 0.7300
# Epoch 115/500
# 10/10 [==============================] - 48s 5s/step - loss: 0.0108 - accuracy: 0.7413
# Epoch 116/500
# 10/10 [==============================] - 45s 4s/step - loss: 0.0121 - accuracy: 0.7406
# Epoch 117/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0119 - accuracy: 0.7258
# Epoch 118/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0124 - accuracy: 0.7295
# Epoch 119/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0161 - accuracy: 0.7462
# Epoch 120/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0146 - accuracy: 0.7077
# Epoch 121/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0103 - accuracy: 0.7343
# Epoch 122/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0103 - accuracy: 0.7433
# Epoch 123/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0105 - accuracy: 0.6784
# Epoch 124/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0124 - accuracy: 0.7488
# Epoch 125/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0101 - accuracy: 0.7029
# Epoch 126/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0440 - accuracy: 0.7417
# Epoch 127/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0120 - accuracy: 0.7226
# Epoch 128/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0126 - accuracy: 0.7446
# Epoch 129/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0137 - accuracy: 0.7384
# Epoch 130/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0125 - accuracy: 0.7385
# Epoch 131/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0111 - accuracy: 0.7046
# Epoch 132/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0118 - accuracy: 0.7326
# Epoch 133/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0125 - accuracy: 0.7282
# Epoch 134/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0121 - accuracy: 0.7063
# Epoch 135/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0096 - accuracy: 0.7560
# Epoch 136/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0131 - accuracy: 0.7046
# Epoch 137/500
# 10/10 [==============================] - 50s 5s/step - loss: 0.0103 - accuracy: 0.6908
# Epoch 138/500
# 10/10 [==============================] - 49s 5s/step - loss: 0.0104 - accuracy: 0.7239
# Epoch 139/500
# 10/10 [==============================] - 48s 5s/step - loss: 0.0141 - accuracy: 0.7368
# Epoch 140/500
# 10/10 [==============================] - 47s 5s/step - loss: 0.0138 - accuracy: 0.7280
# Epoch 141/500
# 10/10 [==============================] - 45s 5s/step - loss: 0.0126 - accuracy: 0.7485
# Epoch 142/500
# 10/10 [==============================] - 46s 5s/step - loss: 0.0123 - accuracy: 0.7425
# Epoch 143/500
# 10/10 [==============================] - 47s 5s/step - loss: 0.0132 - accuracy: 0.7596
# Epoch 144/500
# 10/10 [==============================] - 46s 5s/step - loss: 0.0127 - accuracy: 0.6818
# Epoch 145/500
# 10/10 [==============================] - 46s 5s/step - loss: 0.0111 - accuracy: 0.7423
# Epoch 146/500
# 10/10 [==============================] - 48s 5s/step - loss: 0.0115 - accuracy: 0.7266
# Epoch 147/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0112 - accuracy: 0.7485
# Epoch 148/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0121 - accuracy: 0.7225
# Epoch 149/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0129 - accuracy: 0.7317
# Epoch 150/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0129 - accuracy: 0.7570
# Epoch 151/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0114 - accuracy: 0.7192
# Epoch 152/500
# 10/10 [==============================] - 45s 4s/step - loss: 0.0101 - accuracy: 0.7029
# Epoch 153/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0117 - accuracy: 0.7591
# Epoch 154/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0104 - accuracy: 0.7026
# Epoch 155/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0102 - accuracy: 0.7279
# Epoch 156/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0126 - accuracy: 0.7432
# Epoch 157/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0109 - accuracy: 0.7205
# Epoch 158/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0124 - accuracy: 0.7122
# Epoch 159/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0126 - accuracy: 0.7460
# Epoch 160/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0123 - accuracy: 0.7080
# Epoch 161/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0119 - accuracy: 0.7209
# Epoch 162/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0125 - accuracy: 0.7370
# Epoch 163/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0121 - accuracy: 0.7390
# Epoch 164/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0110 - accuracy: 0.7444
# Epoch 165/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0121 - accuracy: 0.7120
# Epoch 166/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0128 - accuracy: 0.7435
# Epoch 167/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0112 - accuracy: 0.7052
# Epoch 168/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0122 - accuracy: 0.7133
# Epoch 169/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0118 - accuracy: 0.7298
# Epoch 170/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0131 - accuracy: 0.7399
# Epoch 171/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0136 - accuracy: 0.7332
# Epoch 172/500
# 10/10 [==============================] - 44s 4s/step - loss: 0.0125 - accuracy: 0.7147
# Epoch 173/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0131 - accuracy: 0.7324
# Epoch 174/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0109 - accuracy: 0.7613
# Epoch 175/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0126 - accuracy: 0.7728
# Epoch 176/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0095 - accuracy: 0.7245
# Epoch 177/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0114 - accuracy: 0.7438
# Epoch 178/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0148 - accuracy: 0.7113
# Epoch 179/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0113 - accuracy: 0.6878
# Epoch 180/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0121 - accuracy: 0.7016
# Epoch 181/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0141 - accuracy: 0.7265
# Epoch 182/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0129 - accuracy: 0.7199
# Epoch 183/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0129 - accuracy: 0.7538
# Epoch 184/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0108 - accuracy: 0.7344
# Epoch 185/500
# 10/10 [==============================] - 52s 5s/step - loss: 0.0114 - accuracy: 0.7188
# Epoch 186/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0108 - accuracy: 0.7210
# Epoch 187/500
# 10/10 [==============================] - 60s 6s/step - loss: 0.0111 - accuracy: 0.7246
# Epoch 188/500
# 10/10 [==============================] - 61s 6s/step - loss: 0.0121 - accuracy: 0.7033
# Epoch 189/500
# 10/10 [==============================] - 50s 5s/step - loss: 0.0130 - accuracy: 0.7256
# Epoch 190/500
# 10/10 [==============================] - 65s 6s/step - loss: 0.0129 - accuracy: 0.7410
# Epoch 191/500
# 10/10 [==============================] - 54s 5s/step - loss: 0.0133 - accuracy: 0.7473
# Epoch 192/500
# 10/10 [==============================] - 54s 5s/step - loss: 0.0106 - accuracy: 0.7050
# Epoch 193/500
# 10/10 [==============================] - 54s 5s/step - loss: 0.0135 - accuracy: 0.7549
# Epoch 194/500
# 10/10 [==============================] - 54s 5s/step - loss: 0.0123 - accuracy: 0.7811
# Epoch 195/500
# 10/10 [==============================] - 52s 5s/step - loss: 0.0114 - accuracy: 0.7395
# Epoch 196/500
# 10/10 [==============================] - 52s 5s/step - loss: 0.0107 - accuracy: 0.6873
# Epoch 197/500
# 10/10 [==============================] - 60s 6s/step - loss: 0.0126 - accuracy: 0.7087
# Epoch 198/500
# 10/10 [==============================] - 62s 6s/step - loss: 0.0127 - accuracy: 0.7155
# Epoch 199/500
# 10/10 [==============================] - 63s 6s/step - loss: 0.0119 - accuracy: 0.7217
# Epoch 200/500
# 10/10 [==============================] - 63s 6s/step - loss: 0.0122 - accuracy: 0.6918
# Epoch 201/500
# 10/10 [==============================] - 63s 6s/step - loss: 0.0099 - accuracy: 0.7497
# Epoch 202/500
# 10/10 [==============================] - 63s 6s/step - loss: 0.0121 - accuracy: 0.7156
# Epoch 203/500
# 10/10 [==============================] - 64s 6s/step - loss: 0.0128 - accuracy: 0.7290
# Epoch 204/500
# 10/10 [==============================] - 63s 6s/step - loss: 0.0104 - accuracy: 0.7305
# Epoch 205/500
# 10/10 [==============================] - 64s 6s/step - loss: 0.0128 - accuracy: 0.6833
# Epoch 206/500
# 10/10 [==============================] - 64s 6s/step - loss: 0.0119 - accuracy: 0.7604
# Epoch 207/500
# 10/10 [==============================] - 64s 6s/step - loss: 0.0131 - accuracy: 0.7628
# Epoch 208/500
# 10/10 [==============================] - 64s 6s/step - loss: 0.0132 - accuracy: 0.7279
# Epoch 209/500
# 10/10 [==============================] - 64s 6s/step - loss: 0.0127 - accuracy: 0.7107
# Epoch 210/500
# 10/10 [==============================] - 65s 6s/step - loss: 0.0141 - accuracy: 0.7423
# Epoch 211/500
# 10/10 [==============================] - 65s 6s/step - loss: 0.0107 - accuracy: 0.7080
# Epoch 212/500
# 10/10 [==============================] - 65s 7s/step - loss: 0.0126 - accuracy: 0.7230
# Epoch 213/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0119 - accuracy: 0.6979
# Epoch 214/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0117 - accuracy: 0.7283
# Epoch 215/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0097 - accuracy: 0.7338
# Epoch 216/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0122 - accuracy: 0.7092
# Epoch 217/500
# 10/10 [==============================] - 68s 7s/step - loss: 0.0132 - accuracy: 0.7343
# Epoch 218/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0116 - accuracy: 0.7583
# Epoch 219/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0121 - accuracy: 0.7427
# Epoch 220/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0117 - accuracy: 0.7402
# Epoch 221/500
# 10/10 [==============================] - 66s 7s/step - loss: 0.0142 - accuracy: 0.7509
# Epoch 222/500
# 10/10 [==============================] - 66s 7s/step - loss: 0.0120 - accuracy: 0.7358
# Epoch 223/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0106 - accuracy: 0.7028
# Epoch 224/500
# 10/10 [==============================] - 65s 7s/step - loss: 0.0120 - accuracy: 0.7436
# Epoch 225/500
# 10/10 [==============================] - 64s 6s/step - loss: 0.0135 - accuracy: 0.7438
# Epoch 226/500
# 10/10 [==============================] - 62s 6s/step - loss: 0.0127 - accuracy: 0.6867
# Epoch 227/500
# 10/10 [==============================] - 62s 6s/step - loss: 0.0107 - accuracy: 0.6853
# Epoch 228/500
# 10/10 [==============================] - 62s 6s/step - loss: 0.0126 - accuracy: 0.7498
# Epoch 229/500
# 10/10 [==============================] - 62s 6s/step - loss: 0.0108 - accuracy: 0.7457
# Epoch 230/500
# 10/10 [==============================] - 63s 6s/step - loss: 0.0121 - accuracy: 0.7235
# Epoch 231/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0133 - accuracy: 0.7637
# Epoch 232/500
# 10/10 [==============================] - 63s 6s/step - loss: 0.0113 - accuracy: 0.7304
# Epoch 233/500
# 10/10 [==============================] - 62s 6s/step - loss: 0.0129 - accuracy: 0.6876
# Epoch 234/500
# 10/10 [==============================] - 67s 7s/step - loss: 0.0139 - accuracy: 0.7527
# Epoch 235/500
# 10/10 [==============================] - 82s 8s/step - loss: 0.0092 - accuracy: 0.7264
# Epoch 236/500
# 10/10 [==============================] - 76s 8s/step - loss: 0.0117 - accuracy: 0.7059
# Epoch 237/500
# 10/10 [==============================] - 26s 3s/step - loss: 0.0110 - accuracy: 0.7262
# Epoch 238/500
# 10/10 [==============================] - 31s 3s/step - loss: 0.0135 - accuracy: 0.7243
# Epoch 239/500
# 10/10 [==============================] - 42s 4s/step - loss: 0.0128 - accuracy: 0.7680
# Epoch 240/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0108 - accuracy: 0.7556
# Epoch 241/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0121 - accuracy: 0.7173
# Epoch 242/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0134 - accuracy: 0.7343
# Epoch 243/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0114 - accuracy: 0.6970
# Epoch 244/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0112 - accuracy: 0.6765
# Epoch 245/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0123 - accuracy: 0.7696
# Epoch 246/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0130 - accuracy: 0.7004
# Epoch 247/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0133 - accuracy: 0.7317
# Epoch 248/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0105 - accuracy: 0.7052
# Epoch 249/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0119 - accuracy: 0.7584
# Epoch 250/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0135 - accuracy: 0.7164
# Epoch 251/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0123 - accuracy: 0.7436
# Epoch 252/500
# 10/10 [==============================] - 43s 4s/step - loss: 0.0145 - accuracy: 0.7458
# Epoch 253/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0120 - accuracy: 0.7358
# Epoch 254/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0122 - accuracy: 0.7064
# Epoch 255/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0118 - accuracy: 0.7467
# Epoch 256/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0114 - accuracy: 0.7354
# Epoch 257/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0113 - accuracy: 0.6916
# Epoch 258/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0115 - accuracy: 0.7051
# Epoch 259/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0144 - accuracy: 0.7300
# Epoch 260/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0112 - accuracy: 0.7187
# Epoch 261/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0112 - accuracy: 0.7016
# Epoch 262/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0129 - accuracy: 0.7355
# Epoch 263/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0104 - accuracy: 0.7369
# Epoch 264/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0146 - accuracy: 0.7293
# Epoch 265/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0114 - accuracy: 0.7482
# Epoch 266/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0110 - accuracy: 0.7422
# Epoch 267/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0128 - accuracy: 0.7406
# Epoch 268/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0122 - accuracy: 0.6963
# Epoch 269/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0140 - accuracy: 0.7118
# Epoch 270/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0141 - accuracy: 0.7691
# Epoch 271/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0124 - accuracy: 0.7492
# Epoch 272/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0104 - accuracy: 0.7260
# Epoch 273/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0123 - accuracy: 0.7541
# Epoch 274/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0102 - accuracy: 0.7279
# Epoch 275/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0113 - accuracy: 0.6940
# Epoch 276/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0104 - accuracy: 0.7288
# Epoch 277/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0145 - accuracy: 0.7216
# Epoch 278/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0121 - accuracy: 0.7329
# Epoch 279/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0111 - accuracy: 0.7063
# Epoch 280/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0127 - accuracy: 0.7137
# Epoch 281/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0127 - accuracy: 0.7345
# Epoch 282/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0115 - accuracy: 0.7340
# Epoch 283/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0110 - accuracy: 0.7123
# Epoch 284/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0120 - accuracy: 0.7383
# Epoch 285/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0126 - accuracy: 0.7507
# Epoch 286/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0119 - accuracy: 0.7304
# Epoch 287/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0144 - accuracy: 0.7269
# Epoch 288/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0109 - accuracy: 0.7096
# Epoch 289/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0121 - accuracy: 0.7413
# Epoch 290/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0121 - accuracy: 0.6961
# Epoch 291/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0111 - accuracy: 0.7299
# Epoch 292/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0111 - accuracy: 0.7097
# Epoch 293/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0120 - accuracy: 0.7737
# Epoch 294/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0128 - accuracy: 0.7401
# Epoch 295/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0122 - accuracy: 0.6782
# Epoch 296/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0111 - accuracy: 0.7267
# Epoch 297/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0150 - accuracy: 0.7706
# Epoch 298/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0110 - accuracy: 0.7338
# Epoch 299/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0118 - accuracy: 0.7139
# Epoch 300/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0134 - accuracy: 0.7672
# Epoch 301/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0141 - accuracy: 0.7179
# Epoch 302/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0115 - accuracy: 0.7422
# Epoch 303/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0108 - accuracy: 0.7046
# Epoch 304/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0106 - accuracy: 0.7352
# Epoch 305/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0127 - accuracy: 0.7300
# Epoch 306/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0106 - accuracy: 0.6890
# Epoch 307/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0113 - accuracy: 0.7176
# Epoch 308/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0133 - accuracy: 0.7488
# Epoch 309/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0113 - accuracy: 0.7337
# Epoch 310/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0106 - accuracy: 0.7089
# Epoch 311/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0129 - accuracy: 0.7384
# Epoch 312/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0133 - accuracy: 0.7411
# Epoch 313/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0125 - accuracy: 0.7292
# Epoch 314/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0118 - accuracy: 0.7454
# Epoch 315/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0122 - accuracy: 0.7450
# Epoch 316/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0128 - accuracy: 0.7267
# Epoch 317/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0098 - accuracy: 0.7394
# Epoch 318/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0106 - accuracy: 0.6930
# Epoch 319/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0110 - accuracy: 0.7684
# Epoch 320/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0150 - accuracy: 0.7545
# Epoch 321/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0113 - accuracy: 0.6982
# Epoch 322/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0133 - accuracy: 0.7054
# Epoch 323/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0136 - accuracy: 0.7355
# Epoch 324/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0118 - accuracy: 0.7453
# Epoch 325/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0113 - accuracy: 0.6896
# Epoch 326/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0121 - accuracy: 0.7248
# Epoch 327/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0123 - accuracy: 0.7371
# Epoch 328/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0122 - accuracy: 0.7173
# Epoch 329/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0119 - accuracy: 0.7427
# Epoch 330/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0114 - accuracy: 0.7227
# Epoch 331/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0126 - accuracy: 0.6987
# Epoch 332/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0127 - accuracy: 0.7431
# Epoch 333/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0134 - accuracy: 0.7502
# Epoch 334/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0129 - accuracy: 0.7588
# Epoch 335/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0100 - accuracy: 0.6904
# Epoch 336/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0145 - accuracy: 0.7630
# Epoch 337/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0113 - accuracy: 0.7575
# Epoch 338/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0116 - accuracy: 0.7078
# Epoch 339/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0145 - accuracy: 0.7148
# Epoch 340/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0105 - accuracy: 0.7313
# Epoch 341/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0119 - accuracy: 0.7339
# Epoch 342/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0108 - accuracy: 0.6981
# Epoch 343/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0105 - accuracy: 0.7454
# Epoch 344/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0122 - accuracy: 0.7095
# Epoch 345/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0121 - accuracy: 0.7388
# Epoch 346/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0108 - accuracy: 0.7417
# Epoch 347/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0125 - accuracy: 0.7081
# Epoch 348/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0143 - accuracy: 0.7410
# Epoch 349/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0121 - accuracy: 0.7180
# Epoch 350/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0107 - accuracy: 0.6998
# Epoch 351/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0116 - accuracy: 0.7638
# Epoch 352/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0132 - accuracy: 0.7078
# Epoch 353/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0121 - accuracy: 0.7466
# Epoch 354/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0112 - accuracy: 0.7116
# Epoch 355/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0102 - accuracy: 0.7362
# Epoch 356/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0150 - accuracy: 0.7453
# Epoch 357/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0110 - accuracy: 0.7302
# Epoch 358/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0140 - accuracy: 0.7145
# Epoch 359/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0124 - accuracy: 0.7289
# Epoch 360/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0126 - accuracy: 0.7209
# Epoch 361/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0117 - accuracy: 0.7292
# Epoch 362/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0120 - accuracy: 0.7281
# Epoch 363/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0125 - accuracy: 0.7216
# Epoch 364/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0116 - accuracy: 0.7441
# Epoch 365/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0132 - accuracy: 0.7028
# Epoch 366/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0118 - accuracy: 0.7343
# Epoch 367/500
# 10/10 [==============================] - 41s 4s/step - loss: 0.0109 - accuracy: 0.7339
# Epoch 368/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0110 - accuracy: 0.7030
# Epoch 369/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0114 - accuracy: 0.7469
# Epoch 370/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0133 - accuracy: 0.7440
# Epoch 371/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0125 - accuracy: 0.7238
# Epoch 372/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0111 - accuracy: 0.7017
# Epoch 373/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0110 - accuracy: 0.7512
# Epoch 374/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0129 - accuracy: 0.7557
# Epoch 375/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0126 - accuracy: 0.7117
# Epoch 376/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0127 - accuracy: 0.7414
# Epoch 377/500
# 10/10 [==============================] - 40s 4s/step - loss: 0.0111 - accuracy: 0.6909
# Epoch 378/500
# 10/10 [==============================] - 39s 4s/step - loss: 0.0125 - accuracy: 0.7105
# Epoch 379/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0128 - accuracy: 0.7299
# Epoch 380/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0128 - accuracy: 0.7491
# Epoch 381/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0129 - accuracy: 0.7610
# Epoch 382/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0123 - accuracy: 0.7520
# Epoch 383/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0103 - accuracy: 0.6952
# Epoch 384/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0132 - accuracy: 0.7325
# Epoch 385/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0114 - accuracy: 0.7154
# Epoch 386/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0126 - accuracy: 0.7527
# Epoch 387/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0122 - accuracy: 0.7259
# Epoch 388/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0117 - accuracy: 0.7023
# Epoch 389/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0112 - accuracy: 0.7022
# Epoch 390/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0127 - accuracy: 0.7398
# Epoch 391/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0107 - accuracy: 0.7075
# Epoch 392/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0157 - accuracy: 0.7387
# Epoch 393/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0130 - accuracy: 0.7510
# Epoch 394/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0101 - accuracy: 0.7346
# Epoch 395/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0128 - accuracy: 0.7207
# Epoch 396/500
# 10/10 [==============================] - 38s 4s/step - loss: 0.0123 - accuracy: 0.7184
# Epoch 397/500
# 10/10 [==============================] - 37s 4s/step - loss: 0.0135 - accuracy: 0.7466
# Epoch 398/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0097 - accuracy: 0.7334
# Epoch 399/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0120 - accuracy: 0.7172
# Epoch 400/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0114 - accuracy: 0.7337
# Epoch 401/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0113 - accuracy: 0.7189
# Epoch 402/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0129 - accuracy: 0.7384
# Epoch 403/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0115 - accuracy: 0.7082
# Epoch 404/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0132 - accuracy: 0.6977
# Epoch 405/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0127 - accuracy: 0.7442
# Epoch 406/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0132 - accuracy: 0.7257
# Epoch 407/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0120 - accuracy: 0.7554
# Epoch 408/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0119 - accuracy: 0.7462
# Epoch 409/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0110 - accuracy: 0.6797
# Epoch 410/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0127 - accuracy: 0.7203
# Epoch 411/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0118 - accuracy: 0.7005
# Epoch 412/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0113 - accuracy: 0.7511
# Epoch 413/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0133 - accuracy: 0.7862
# Epoch 414/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0109 - accuracy: 0.6815
# Epoch 415/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0103 - accuracy: 0.7258
# Epoch 416/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0123 - accuracy: 0.7313
# Epoch 417/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0136 - accuracy: 0.7591
# Epoch 418/500
# 10/10 [==============================] - 35s 3s/step - loss: 0.0130 - accuracy: 0.7334
# Epoch 419/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0129 - accuracy: 0.7251
# Epoch 420/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0117 - accuracy: 0.7043
# Epoch 421/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0134 - accuracy: 0.7125
# Epoch 422/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0115 - accuracy: 0.7121
# Epoch 423/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0105 - accuracy: 0.7306
# Epoch 424/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0126 - accuracy: 0.7597
# Epoch 425/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0126 - accuracy: 0.7425
# Epoch 426/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0107 - accuracy: 0.7066
# Epoch 427/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0136 - accuracy: 0.7403
# Epoch 428/500
# 10/10 [==============================] - 35s 3s/step - loss: 0.0131 - accuracy: 0.7413
# Epoch 429/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0105 - accuracy: 0.7240
# Epoch 430/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0119 - accuracy: 0.7037
# Epoch 431/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0135 - accuracy: 0.7028
# Epoch 432/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0138 - accuracy: 0.7688
# Epoch 433/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0111 - accuracy: 0.7655
# Epoch 434/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0122 - accuracy: 0.7100
# Epoch 435/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0126 - accuracy: 0.7634
# Epoch 436/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0112 - accuracy: 0.7164
# Epoch 437/500
# 10/10 [==============================] - 35s 3s/step - loss: 0.0105 - accuracy: 0.7155
# Epoch 438/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0113 - accuracy: 0.7230
# Epoch 439/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0111 - accuracy: 0.7007
# Epoch 440/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0148 - accuracy: 0.7524
# Epoch 441/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0100 - accuracy: 0.7059
# Epoch 442/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0110 - accuracy: 0.7117
# Epoch 443/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0127 - accuracy: 0.7259
# Epoch 444/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0120 - accuracy: 0.7239
# Epoch 445/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0121 - accuracy: 0.7500
# Epoch 446/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0140 - accuracy: 0.7670
# Epoch 447/500
# 10/10 [==============================] - 35s 3s/step - loss: 0.0116 - accuracy: 0.7175
# Epoch 448/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0152 - accuracy: 0.7354
# Epoch 449/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0124 - accuracy: 0.7290
# Epoch 450/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0122 - accuracy: 0.7391
# Epoch 451/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0109 - accuracy: 0.7395
# Epoch 452/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0108 - accuracy: 0.7195
# Epoch 453/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0133 - accuracy: 0.6849
# Epoch 454/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0136 - accuracy: 0.7307
# Epoch 455/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0113 - accuracy: 0.7513
# Epoch 456/500
# 10/10 [==============================] - 35s 3s/step - loss: 0.0104 - accuracy: 0.7256
# Epoch 457/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0122 - accuracy: 0.7459
# Epoch 458/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0117 - accuracy: 0.7082
# Epoch 459/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0114 - accuracy: 0.7446
# Epoch 460/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0119 - accuracy: 0.7006
# Epoch 461/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0113 - accuracy: 0.7693
# Epoch 462/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0121 - accuracy: 0.7240
# Epoch 463/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0129 - accuracy: 0.7470
# Epoch 464/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0136 - accuracy: 0.7361
# Epoch 465/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0129 - accuracy: 0.7065
# Epoch 466/500
# 10/10 [==============================] - 35s 3s/step - loss: 0.0110 - accuracy: 0.6980
# Epoch 467/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0123 - accuracy: 0.7464
# Epoch 468/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0109 - accuracy: 0.7300
# Epoch 469/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0138 - accuracy: 0.7471
# Epoch 470/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0101 - accuracy: 0.7119
# Epoch 471/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0124 - accuracy: 0.7268
# Epoch 472/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0152 - accuracy: 0.7373
# Epoch 473/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0126 - accuracy: 0.7366
# Epoch 474/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0115 - accuracy: 0.7104
# Epoch 475/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0107 - accuracy: 0.7198
# Epoch 476/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0112 - accuracy: 0.7109
# Epoch 477/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0122 - accuracy: 0.7340
# Epoch 478/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0133 - accuracy: 0.7668
# Epoch 479/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0115 - accuracy: 0.7101
# Epoch 480/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0129 - accuracy: 0.7118
# Epoch 481/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0105 - accuracy: 0.7330
# Epoch 482/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0121 - accuracy: 0.7221
# Epoch 483/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0108 - accuracy: 0.7223
# Epoch 484/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0146 - accuracy: 0.7475
# Epoch 485/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0139 - accuracy: 0.7478
# Epoch 486/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0145 - accuracy: 0.7134
# Epoch 487/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0091 - accuracy: 0.7368
# Epoch 488/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0119 - accuracy: 0.7519
# Epoch 489/500
# 10/10 [==============================] - 36s 4s/step - loss: 0.0137 - accuracy: 0.7655
# Epoch 490/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0126 - accuracy: 0.7081
# Epoch 491/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0127 - accuracy: 0.7064
# Epoch 492/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0106 - accuracy: 0.7386
# Epoch 493/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0108 - accuracy: 0.7063
# Epoch 494/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0115 - accuracy: 0.7126
# Epoch 495/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0104 - accuracy: 0.7473
# Epoch 496/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0112 - accuracy: 0.7379
# Epoch 497/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0131 - accuracy: 0.7445
# Epoch 498/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0125 - accuracy: 0.7189
# Epoch 499/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0116 - accuracy: 0.7261
# Epoch 500/500
# 10/10 [==============================] - 35s 4s/step - loss: 0.0133 - accuracy: 0.7327

# %%
np.save('my_history.npy',history.history)

history2=np.load('my_history.npy',allow_pickle='TRUE').item()
print(history2.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
# Save model
model_json = model.to_json()
with open("modelNew_14_09.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("modelNew_14_09.h5")

# %% [markdown]
# ### Training and test data

# %%
for x in range(3):
    display(Image.open('../images/Images_version_5/Test/100' + str(x) + '_256.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x18453226E48>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x182AF96A788>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x182AFA20A08>

# %%
# Colorizer section 
images_to_color = []
for filename in os.listdir('../images/Images_version_5/Test/'):
    images_to_color.append(img_to_array(load_img('../images/Images_version_5/Test/'+filename)))

# convert color space, reshape img
images_to_color = np.array(images_to_color, dtype=float)
images_to_color = rgb2lab(1.0/255*images_to_color)[:,:,:,0]
images_to_color = images_to_color.reshape(images_to_color.shape+(1,))

# Test model with predict() function
output = model.predict(images_to_color)

# covert color value back from [-1,1] to [-128,128] which is Lab color spectrum
output = output * 128

# Output colorizations
for i in range(len(output)):
    cur = np.zeros((256, 256, 3))            # make empty 256x256 with 3 layers
    cur[:,:,0] = images_to_color[i][:,:,0]   # copy grayscale layer to new obj
    cur[:,:,1:] = output[i]                  # copy color layer to new obj
    # save img in directory
    imsave("../images/Images_version_5/Result/img_"+str(i)+".png", lab2rgb(cur))
# Out:
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 11 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 31 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 28 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 7 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 69 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 98 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 22 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 17 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\setr7\miniconda3\lib\site-packages\skimage\color\colorconv.py:1128: UserWarning: Color data out of range: Z < 0 in 72 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
for x in range(3):
    display(Image.open('../images/Images_version_5/Result/img_' + str(x) + '.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x182A41B71C8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x1845309AA88>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x1845309AA88>
